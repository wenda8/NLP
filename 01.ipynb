# %%
from dataclasses import dataclass
from typing import Optional
from yargy import Parser, rule, and_, or_
from yargy.predicates import gram, is_capitalized, dictionary, normalized, gte, lte, dictionary, caseless
from yargy.interpretation import fact
from yargy.pipelines import morph_pipeline
from yargy.relations import gnc_relation

# %%
@dataclass
class Entry:
    name: str
    birth_date: Optional[str]
    birth_place: Optional[str]

# %%
Name = fact(
    "Name",
    ["first", "last"]
)
gnc = gnc_relation()
NAME = rule(
    is_capitalized().match(gnc).interpretation(Name.first.inflected()).optional(),
    is_capitalized().match(gnc).interpretation(Name.last.inflected()),
).interpretation(Name)

# %%
Birthdate = fact(
    "Birthdate",
    ["day","month","year"]
)

MONTHS = {"январь", "февраль", "март", "апрель", 
    "мая", "июнь", "июль", "август", 
    "сентябрь", "октябрь", "ноябрь", "декабрь"}
    
YEAR_WORDS = or_(
    rule(caseless('г'),'.'),
    rule(normalized('год'))
)

DAY = and_(
    gte(1),
    lte(31)
).interpretation(Birthdate.day)

MONTH = and_(
    gte(1),
    lte(12)
).interpretation(Birthdate.month)

MONTH_NAME = dictionary(MONTHS).interpretation(Birthdate.month)

YEAR = and_(
    gte(1000),
    lte(2024),
).interpretation(Birthdate.year)

WORDS_DATE = morph_pipeline([
    "в",
])

BIRTH_DATE = or_(
    rule(
        DAY,
        MONTH_NAME,
    ),
    rule(
        DAY,
        MONTH,
    ),
    rule(
        DAY,
        MONTH_NAME,
        YEAR,
        YEAR_WORDS.optional()
    ),
    rule(
        WORDS_DATE,
        YEAR,
        YEAR_WORDS.optional()
    )
).interpretation(Birthdate)

# %%
Birthplace = fact(
    "Birthplace",
    ["birth_place"]
)

WORDS_PLACE = morph_pipeline([
    "в",
    "на",
])

PLACE = and_(
    is_capitalized(), 
    gram('NOUN')
).interpretation(Birthplace.birth_place)

BIRTH_PLACE = rule(
    WORDS_PLACE,
    PLACE
).interpretation(Birthplace)

# %%
Person = fact(
    'Person',
    ['name', 'birth_date', 'birth_place']
)

KEYWORDS = morph_pipeline([
    "родился", 
    "родилась", 
    "день рождения",
    "дата рождения",
    "рожден",
    "рождена"
])

# %%
RULE1 = rule(
        NAME.interpretation(Person.name), 
        KEYWORDS,
        BIRTH_DATE.interpretation(Person.birth_date), 
        BIRTH_PLACE.interpretation(Person.birth_place)
).interpretation(Person)

RULE2 = rule(
        NAME.interpretation(Person.name), 
        KEYWORDS,
        BIRTH_PLACE.interpretation(Person.birth_place),
        BIRTH_DATE.interpretation(Person.birth_date)
).interpretation(Person)

PERSON_RULE = or_(
        RULE1,
        RULE2
).interpretation(Person)

# %%
parser = Parser(PERSON_RULE)
def extract_person_data(file_path):
    entries = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            try:
                parts = line.strip().split('\t')
                text_to_parse = parts[2] if len(parts) > 2 else ""

                for match in parser.findall(text_to_parse):
                    person = match.fact
                    entries.append(Entry(person.name, person.birth_date, person.birth_place))
            except AttributeError as e:
                print(f"Error processing line: {line.strip()} | Error: {e}")
                continue
    return entries

# %%
file_path = "D:/xuexi/nlp/nlp-2023-master/data/news.txt"
person_entries = extract_person_data(file_path)

for entry in person_entries:
    print(f"Name: {entry.name}, Birth Date: {entry.birth_date}, Birth Place: {entry.birth_place}")
# Out:
# Name: Name(first='бетси', last='палмера'), Birth Date: Birthdate(day=None, month=None, year='1926'), Birth Place: Birthplace(birth_place='США')
# Name: Name(first=None, last='трэмиел'), Birth Date: Birthdate(day=None, month=None, year='1928'), Birth Place: Birthplace(birth_place='Польше')
# Name: Name(first=None, last='он'), Birth Date: Birthdate(day='11', month='сентября', year='1865'), Birth Place: Birthplace(birth_place='Польше')
# Name: Name(first=None, last='ребёнок'), Birth Date: Birthdate(day='25', month='декабря', year=None), Birth Place: Birthplace(birth_place='Калифорнии')
# Name: Name(first='дмитрий', last='чернявский'), Birth Date: Birthdate(day='5', month='марта', year='1992'), Birth Place: Birthplace(birth_place='Артемовске')
# Name: Name(first=None, last='миллиардер'), Birth Date: Birthdate(day=None, month=None, year='1938'), Birth Place: Birthplace(birth_place='Лондоне')
# Name: Name(first='яковлевюрий', last='яковлев'), Birth Date: Birthdate(day=None, month=None, year='1928'), Birth Place: Birthplace(birth_place='Москве')
# Name: Name(first=None, last='патрик'), Birth Date: Birthdate(day=None, month=None, year='1990'), Birth Place: Birthplace(birth_place='Бронксе')
# Name: Name(first='николай', last='караченцов'), Birth Date: Birthdate(day='27', month='октября', year='1944'), Birth Place: Birthplace(birth_place='Москве')
# Name: Name(first=None, last='живописец'), Birth Date: Birthdate(day='25', month='мая', year='1927'), Birth Place: Birthplace(birth_place='Сочи')
# Name: Name(first='игорь', last='доценко'), Birth Date: Birthdate(day=None, month=None, year='1953'), Birth Place: Birthplace(birth_place='Хмельницкой')
# Name: Name(first=None, last='энгельбарт'), Birth Date: Birthdate(day=None, month=None, year='1925'), Birth Place: Birthplace(birth_place='США')
# Name: Name(first='инна', last='лиснянская'), Birth Date: Birthdate(day=None, month=None, year='1928'), Birth Place: Birthplace(birth_place='Баку')
# Name: Name(first=None, last='гамильтон'), Birth Date: Birthdate(day=None, month=None, year='1922'), Birth Place: Birthplace(birth_place='Лондоне')
# Name: Name(first='раймонд', last='паулс'), Birth Date: Birthdate(day='12', month='января', year='1936'), Birth Place: Birthplace(birth_place='Риге')
# Name: Name(first='юлия', last='пастрана'), Birth Date: Birthdate(day=None, month=None, year='1834'), Birth Place: Birthplace(birth_place='Мексике')
# Name: Name(first='эдвард', last='мунк'), Birth Date: Birthdate(day='12', month='декабря', year='1863'), Birth Place: Birthplace(birth_place='Летене')
# Name: Name(first='татьяна', last='самойлова'), Birth Date: Birthdate(day='4', month='мая', year='1934'), Birth Place: Birthplace(birth_place='Ленинграде')
# Name: Name(first=None, last='рахлина'), Birth Date: Birthdate(day=None, month=None, year='1938'), Birth Place: Birthplace(birth_place='Ленинграде')
# Name: Name(first='владимир', last='высоцкий'), Birth Date: Birthdate(day=None, month=None, year='1938'), Birth Place: Birthplace(birth_place='Москве')
# Name: Name(first=None, last='монро'), Birth Date: Birthdate(day=None, month=None, year='1969'), Birth Place: Birthplace(birth_place='Ленинграде')
# Name: Name(first=None, last='ельчин'), Birth Date: Birthdate(day='11', month='марта', year='1989'), Birth Place: Birthplace(birth_place='Ленинграде')
# Name: Name(first='борис', last='васильев'), Birth Date: Birthdate(day='21', month='мая', year='1924'), Birth Place: Birthplace(birth_place='Смоленске')
# Name: Name(first=None, last='донде'), Birth Date: Birthdate(day='3', month='февраля', year='1909'), Birth Place: Birthplace(birth_place='Саратове')
# Name: Name(first='александр', last='луи'), Birth Date: Birthdate(day='22', month='июля', year=None), Birth Place: Birthplace(birth_place='Лондоне')
# Name: Name(first=None, last='искусствовед'), Birth Date: Birthdate(day=None, month=None, year='1925'), Birth Place: Birthplace(birth_place='Сарапуле')
# Name: Name(first='евгений', last='гришковец'), Birth Date: Birthdate(day=None, month=None, year='1967'), Birth Place: Birthplace(birth_place='Кемерово')
# Name: Name(first='игорь', last='кваша'), Birth Date: Birthdate(day=None, month=None, year='1933'), Birth Place: Birthplace(birth_place='Москве')
# Name: Name(first='полина', last='жеребцова'), Birth Date: Birthdate(day=None, month=None, year='1985'), Birth Place: Birthplace(birth_place='Грозном')
# Name: Name(first=None, last='споканимая'), Birth Date: Birthdate(day='26', month='марта', year='1931'), Birth Place: Birthplace(birth_place='Бостоне')
# Name: Name(first=None, last='казенин'), Birth Date: Birthdate(day='21', month='мая', year='1937'), Birth Place: Birthplace(birth_place='Кирове')
# Name: Name(first='алексей', last='ремизов'), Birth Date: Birthdate(day=None, month=None, year='1877'), Birth Place: Birthplace(birth_place='Москве')
# Name: Name(first='михаил', last='алгаш'), Birth Date: Birthdate(day=None, month=None, year='1988'), Birth Place: Birthplace(birth_place='Омске')
